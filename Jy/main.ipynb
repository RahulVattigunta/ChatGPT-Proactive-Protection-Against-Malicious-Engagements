# %%
# !pip install transformers
# !pip install evaluate

from transformers import logging
logging.set_verbosity(logging.WARNING)
# Out:
# Collecting transformers
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/43.7 kB 330.3 kB/s eta 0:00:01
#      ----------------------------------- -- 41.0/43.7 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 43.7/43.7 kB 355.5 kB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (3.14.0)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (2024.5.10)
# Requirement already satisfied: requests in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.5 MB 1.6 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/9.5 MB 4.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/9.5 MB 8.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.4/9.5 MB 13.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.8/9.5 MB 17.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.1/9.5 MB 20.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.5 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 23.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 21.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.5 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.5 MB 19.0 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 16.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#    ---------------------------------------- 0.0/417.5 kB ? eta -:--:--
#    ---------------------------------------- 417.5/417.5 kB ? eta 0:00:00
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.23.0
#     Uninstalling huggingface-hub-0.23.0:
#       Successfully uninstalled huggingface-hub-0.23.0
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\rvattigunta1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\rvattigunta1\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\rvattigunta1\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (4.66.4)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (0.24.5)
# Requirement already satisfied: packaging in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Collecting pyarrow>=15.0.0 (from datasets>=2.0.0->evaluate)
#   Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting requests>=2.19.0 (from evaluate)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp (from datasets>=2.0.0->evaluate)
#   Downloading aiohttp-3.10.3-cp311-cp311-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->evaluate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->evaluate) (2024.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets>=2.0.0->evaluate)
#   Downloading aiohappyeyeballs-2.3.6-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.0.0->evaluate)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.0.0->evaluate)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.0.0->evaluate)
#   Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=2.0.0->evaluate)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rvattigunta1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.1 kB ? eta -:--:--
#    ----------------------------- ---------- 61.4/84.1 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 84.1/84.1 kB 1.6 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ---------------------------------------- 0.0/527.3 kB ? eta -:--:--
#    ------------------------- -------------- 337.9/527.3 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 527.3/527.3 kB 6.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    ---------------------------------------- 143.5/143.5 kB 8.3 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl (29 kB)
# Downloading aiohttp-3.10.3-cp311-cp311-win_amd64.whl (378 kB)
#    ---------------------------------------- 0.0/378.6 kB ? eta -:--:--
#    --------------------------------------- 378.6/378.6 kB 23.0 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp311-cp311-win_amd64.whl (25.2 MB)
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.2 MB 22.0 MB/s eta 0:00:02
#    --- ------------------------------------ 2.5/25.2 MB 26.1 MB/s eta 0:00:01
#    ------ --------------------------------- 4.1/25.2 MB 29.3 MB/s eta 0:00:01
#    --------- ------------------------------ 5.8/25.2 MB 30.9 MB/s eta 0:00:01
#    ------------ --------------------------- 7.9/25.2 MB 36.2 MB/s eta 0:00:01
#    --------------- ------------------------ 9.9/25.2 MB 37.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 10.4/25.2 MB 32.7 MB/s eta 0:00:01
#    -------------------- ------------------- 12.6/25.2 MB 38.6 MB/s eta 0:00:01
#    --------------------- ------------------ 13.6/25.2 MB 34.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.4/25.2 MB 34.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 15.1/25.2 MB 29.7 MB/s eta 0:00:01
#    --------------------------- ------------ 17.1/25.2 MB 29.7 MB/s eta 0:00:01
#    ------------------------------ --------- 19.1/25.2 MB 29.7 MB/s eta 0:00:01
#    -------------------------------- ------- 20.4/25.2 MB 29.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.1/25.2 MB 29.7 MB/s eta 0:00:01
#    -------------------------------------- - 24.0/25.2 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.2 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.2 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.2 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.2 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 23.3 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.3.6-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB ? eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl (28 kB)
# Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.7 kB ? eta -:--:--
#    ---------------------------------------- 76.7/76.7 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, requests, pyarrow, multidict, frozenlist, dill, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets, evaluate
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed aiohappyeyeballs-2.3.6 aiohttp-3.10.3 aiosignal-1.3.1 datasets-2.21.0 dill-0.3.8 evaluate-0.4.2 frozenlist-1.4.1 multidict-6.0.5 multiprocess-0.70.16 pyarrow-17.0.0 requests-2.32.3 xxhash-3.4.1 yarl-1.9.4
#   WARNING: The script datasets-cli.exe is installed in 'C:\Users\rvattigunta1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script evaluate-cli.exe is installed in 'C:\Users\rvattigunta1\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\rvattigunta1\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().system('pip install transformers')
#       2 get_ipython().system('pip install evaluate')
# ----> 4 from transformers import logging
#       5 logging.set_verbosity(logging.WARNING)
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import pandas as pd
import torch

# Load the car reviews dataset
file_path = "data/car_reviews.csv"
df = pd.read_csv(file_path, delimiter=";")
